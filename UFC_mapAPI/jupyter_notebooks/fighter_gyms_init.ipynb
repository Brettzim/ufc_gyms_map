# %%
import requests
from bs4 import BeautifulSoup
import json
from datetime import datetime
import os
import shutil

# %%
URL = 'https://www.ufc.com/rankings'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')
weightclass = soup.findAll('div', attrs={'class':'view-grouping'})

# %%
# Dictionary to store the information
rankings = {}

# Function to extract athlete data from a row
def extract_athlete_data(row):
    rank = row.select_one('.views-field-weight-class-rank').text.strip()
    name = row.select_one('.views-field-title a').text.strip()
    return rank, name

# Iterate over all view groupings (weight classes)
for grouping in soup.select('.view-grouping'):
    # Extract the weight class name
    weight_class = grouping.select_one('.view-grouping-header').text.strip()
    # Initialize a dictionary for this weight class
    rankings[weight_class] = {}
    
    # Extract champion if present
    champion_section = grouping.select_one('.rankings--athlete--champion .info h5 a')
    if champion_section:
        champion_name = champion_section.text.strip()
        rankings[weight_class]['Champion'] = champion_name
    
    # Extract other athletes
    rows = grouping.select('tbody tr')
    for row in rows:
        rank, name = extract_athlete_data(row)
        rankings[weight_class][rank] = name

# Print the resulting dictionary
for weight_class, athletes in rankings.items():
    print(f"Weight Class: {weight_class}")
    for rank, name in athletes.items():
        print(f"  {rank}: {name}")
# Out:
# Weight Class: Men's Pound-for-Pound Top Rank
#   Champion: Islam Makhachev
#   1: Islam Makhachev
#   2: Alex Pereira
#   3: Jon Jones
#   4: Ilia Topuria
#   5: Sean O'Malley
#   6: Belal Muhammad
#   7: Leon Edwards
#   8: Alexander Volkanovski
#   9: Tom Aspinall
#   10: Max Holloway
#   11: Dricus Du Plessis
#   12: Alexandre Pantoja
#   13: Israel Adesanya
#   14: Sean Strickland
#   15: Charles Oliveira
# Weight Class: Flyweight
#   Champion: Alexandre Pantoja
#   1: Brandon Royval
#   2: Brandon Moreno
#   3: Amir Albazi
#   4: Kai Kara-France
#   5: Tatsuro Taira
#   6: Alex Perez
#   7: Steve Erceg
#   8: Matheus Nicolau
#   9: Manel Kape
#   10: Tim Elliott
#   11: Matt Schnell
#   12: Tagir Ulanbekov
#   13: Bruno Silva
#   14: Asu Almabayev
#   15: Cody Durden
# Weight Class: Bantamweight
#   Champion: Sean O'Malley
#   1: Merab Dvalishvili
#   2: Cory Sandhagen
#   3: Petr Yan
#   4: Marlon Vera
#   5: Henry Cejudo
#   6: Deiveson Figueiredo
#   7: Song Yadong
#   8: José Aldo
#   9: Rob Font
#   10: Umar Nurmagomedov
#   11: Kyler Phillips
#   12: Mario Bautista
#   13: Dominick Cruz
#   14: Jonathan Martinez
#   15: Montel Jackson
# Weight Class: Featherweight
#   Champion: Ilia Topuria
#   1: Alexander Volkanovski
#   2: Max Holloway
#   3: Brian Ortega
#   4: Yair Rodriguez
#   5: Movsar Evloev
#   7: Josh Emmett
#   8: Aljamain Sterling
#   9: Calvin Kattar
#   10: Giga Chikadze
#   11: Lerone Murphy
#   12: Diego Lopes
#   13: Bryce Mitchell
#   14: Dan Ige
#   15: Edson Barboza
# Weight Class: Lightweight
#   Champion: Islam Makhachev
#   1: Arman Tsarukyan
#   2: Charles Oliveira
#   3: Justin Gaethje
#   4: Dustin Poirier
#   5: Mateusz Gamrot
#   6: Michael Chandler
#   7: Beneil Dariush
#   8: Rafael Fiziev
#   9: Max Holloway
#   10: Renato Moicano
#   11: Dan Hooker
#   12: Benoît Saint Denis
#   13: Jalin Turner
#   14: Rafael Dos Anjos
#   15: Paddy Pimblett
# Weight Class: Welterweight
#   Champion: Belal Muhammad
#   1: Leon Edwards
#   2: Kamaru Usman
#   3: Shavkat Rakhmonov
#   4: Colby Covington
#   5: Jack Della Maddalena
#   6: Gilbert Burns
#   7: Ian Machado Garry
#   8: Sean Brady
#   9: Stephen Thompson
#   10: Geoff Neal
#   11: Joaquin Buckley
#   12: Neil Magny
#   13: Vicente Luque
#   14: Michael Page
#   15: Kevin Holland
# Weight Class: Middleweight
#   Champion: Dricus Du Plessis
#   1: Sean Strickland
#   2: Israel Adesanya
#   3: Robert Whittaker
#   4: Nassourdine Imavov
#   5: Jared Cannonier
#   6: Marvin Vettori
#   7: Brendan Allen
#   8: Paulo Costa
#   9: Jack Hermansson
#   10: Roman Dolidze
#   11: Khamzat Chimaev
#   12: Caio Borralho
#   13: Michel Pereira
#   14: Anthony Hernandez
#   15: Chris Curtis
# Weight Class: Light Heavyweight
#   Champion: Alex Pereira
#   1: Jiří Procházka
#   2: Magomed Ankalaev
#   3: Jamahal Hill
#   4: Jan Błachowicz
#   5: Aleksandar Rakić
#   6: Nikita Krylov
#   7: Volkan Oezdemir
#   8: Khalil Rountree Jr.
#   9: Johnny Walker
#   10: Carlos Ulberg
#   11: Anthony Smith
#   12: Bogdan Guskov
#   13: Dominick Reyes
#   14: Azamat Murzakanov
#   15: Alonzo Menifield
# Weight Class: Heavyweight
#   Champion: Jon Jones
#   1: Tom Aspinall
#   2: Ciryl Gane
#   3: Alexander Volkov
#   4: Sergei Pavlovich
#   5: Curtis Blaydes
#   6: Stipe Miocic
#   7: Jailton Almeida
#   8: Marcin Tybura
#   9: Serghei Spivac
#   10: Tai Tuivasa
#   11: Derrick Lewis
#   12: Jairzinho Rozenstruik
#   13: Alexandr Romanov
#   14: Marcos Rogerio de Lima
#   15: Rodrigo Nascimento
# Weight Class: Women's Pound-for-Pound Top Rank
#   Champion: Alexa Grasso
#   1: Alexa Grasso
#   2: Zhang Weili
#   3: Valentina Shevchenko
#   4: Manon Fiorot
#   5: Julianna Peña
#   6: Raquel Pennington
#   7: Rose Namajunas
#   8: Erin Blanchfield
#   9: Tatiana Suarez
#   10: Yan Xiaonan
#   11: Jéssica Andrade
#   12: Kayla Harrison
#   13: Virna Jandiroba
#   14: Ketlen Vieira
#   15: Amanda Lemos
# Weight Class: Women's Strawweight
#   Champion: Zhang Weili
#   1: Tatiana Suarez
#   2: Yan Xiaonan
#   3: Virna Jandiroba
#   4: Jéssica Andrade
#   5: Amanda Lemos
#   6: Marina Rodriguez
#   7: Mackenzie Dern
#   8: Amanda Ribas
#   9: Angela Hill
#   10: Loopy Godinez
#   11: Tabatha Ricci
#   12: Luana Pinheiro
#   13: Gillian Robertson
#   14: Iasmin Lucindo
#   15: Karolina Kowalkiewicz
# Weight Class: Women's Flyweight
#   Champion: Alexa Grasso
#   1: Valentina Shevchenko
#   2: Manon Fiorot
#   3: Erin Blanchfield
#   4: Maycee Barber
#   5: Rose Namajunas
#   6: Jéssica Andrade
#   7: Katlyn Cerminara
#   8: Natalia Silva
#   9: Amanda Ribas
#   10: Viviane Araújo
#   11: Karine Silva
#   12: Tracy Cortez
#   13: Ariane da Silva
#   14: Jasmine Jasudavicius
#   15: Casey O'Neill
# Weight Class: Women's Bantamweight
#   Champion: Raquel Pennington
#   1: Julianna Peña
#   2: Ketlen Vieira
#   3: Kayla Harrison
#   4: Irene Aldana
#   5: Macy Chiasson
#   6: Mayra Bueno Silva
#   7: Holly Holm
#   8: Karol Rosa
#   9: Miesha Tate
#   10: Norma Dumont
#   11: Pannie Kianzad
#   12: Yana Santos
#   13: Julia Avila
#   14: Chelsea Chandler
#   15: Germaine de Randamie

# %%
del rankings["Men's Pound-for-Pound Top Rank"]

# %%
# Initialize an empty dictionary
fighter_gym_dict = {}

for weight_class, fighters in rankings.items():

    # List of fighter names
    names = list(fighters.values())

    for i in names:
        name = i.replace(' ', '-')  # Replace spaces with hyphens for the URL
        fighterURL = 'https://www.ufc.com/athlete/' + name
        page = requests.get(fighterURL)
        soup = BeautifulSoup(page.content, 'html.parser')

        # Find the gym location (assuming it is in the third div with class 'c-bio__text')
        gym_div = soup.findAll('div', attrs={'class': 'c-bio__text'})

        if len(gym_div) > 2:
            gym_name = gym_div[2].text.strip()  # Get gym name and remove extra spaces
        else:
            gym_name = "Gym information not found"  # Handle cases where gym info is missing

        # Add to the dictionary
        fighter_gym_dict[i] = gym_name

    # Print the dictionary
fighter_gym_dict
# Out:
# {'Alexandre Pantoja': 'American Top Team',
#  'Brandon Royval': 'Factory X',
#  'Brandon Moreno': 'Jiu-Jitsu',
#  'Amir Albazi': 'Xtreme Couture - Las Vegas, NV',
#  'Kai Kara-France': 'City Kickboxing',
#  'Tatsuro Taira': '24',
#  'Alex Perez': 'Syndicate MMA',
#  'Steve Erceg': 'MMA',
#  'Matheus Nicolau': 'Nova Uniao - Rio de Janeiro',
#  'Manel Kape': 'Xtreme Couture - Las Vegas, NV',
#  'Tim Elliott': 'Freestyle',
#  'Matt Schnell': 'Boxing',
#  'Tagir Ulanbekov': 'Eagles MMA Team',
#  'Bruno Silva': 'Grappler',
#  'Asu Almabayev': 'Gym information not found',
#  'Cody Durden': 'American Top Team',
#  "Sean O'Malley": 'MMA LAB - Glendale, AZ',
#  'Merab Dvalishvili': 'Team Serra/Longo',
#  'Cory Sandhagen': 'MMA',
#  'Petr Yan': 'Team Yan',
#  'Marlon Vera': 'Grappler',
#  'Henry Cejudo': 'Fight Ready - Scottsdale, AZ',
#  'Deiveson Figueiredo': 'Team Figueiredo',
#  'Song Yadong': 'Team Alpha Male',
#  'José Aldo': 'Nova União',
#  'Rob Font': 'Sityodtong - Boston',
#  'Umar Nurmagomedov': 'MMA',
#  'Kyler Phillips': 'The MMA Lab',
#  'Mario Bautista': 'The MMA Lab',
#  'Dominick Cruz': 'Alliance Training Center East -Santee',
#  'Jonathan Martinez': 'Factory X',
#  'Montel Jackson': 'Pura Vida BJJ & MMA',
#  'Ilia Topuria': 'Brazilian Jiu-Jitsu',
#  'Alexander Volkanovski': 'Freestyle Fighting Gym',
#  'Max Holloway': 'Hawaii Elite MMA - Hawaii',
#  'Brian Ortega': 'Team Ortega',
#  'Yair Rodriguez': 'Izzystyle wrestling & VFS Chicago',
#  'Arnold Allen': 'BKK / Tristar',
#  'Josh Emmett': "Team Alpha Male  (Urijah Faber's Ultimate Fitness)",
#  'Aljamain Sterling': 'Serra-Longo - Long Island, NY',
#  'Calvin Kattar': 'New England MMA',
#  'Giga Chikadze': 'Kings MMA',
#  'Lerone Murphy': 'All Powers Gym',
#  'Diego Lopes': 'Jiu-Jitsu',
#  'Bryce Mitchell': 'MMA',
#  'Dan Ige': 'Jiu-Jitsu',
#  'Edson Barboza': 'Ricardo Almeida / Valor MMA',
#  'Islam Makhachev': 'AKA (American Kickboxing Academy) San Jose',
#  'Arman Tsarukyan': 'Syndicate MMA - Las Vegas, NV',
#  'Charles Oliveira': "Bronx's Gold Team",
#  'Justin Gaethje': 'Genesis Training Center',
#  'Dustin Poirier': 'American Top Team ATT Coconut Creek, FL',
#  'Mateusz Gamrot': 'American Top Team',
#  'Michael Chandler': 'Sanford MMA',
#  'Beneil Dariush': 'Kings MMA - Huntington Beach, CA',
#  'Rafael Fiziev': 'Tiger Muay Thai - Phuket, Thailand',
#  'Renato Moicano': 'American Top Team',
#  'Dan Hooker': 'Saigon Sports Club- Vietnam',
#  'Benoît Saint Denis': 'Venum Training Camp Paris',
#  'Jalin Turner': 'MMA',
#  'Rafael Dos Anjos': 'Kings MMA - Huntington Beach, CA',
#  'Paddy Pimblett': 'NEXT Generation MMA',
#  'Belal Muhammad': 'Roufusport, (Mikwaukee, WI) & Chicago Fight Team (Chicago, IL)',
#  'Leon Edwards': 'UTC Ultimate Training Centre Birmingham',
#  'Kamaru Usman': 'Blackzilians - Boca Raton, FL',
#  'Shavkat Rakhmonov': 'Kill Cliff FC',
#  'Colby Covington': 'MMA Masters - Miami, FL',
#  'Jack Della Maddalena': 'MMA',
#  'Gilbert Burns': 'Jaco Hybrid Training Center',
#  'Ian Machado Garry': 'Gym information not found',
#  'Sean Brady': 'Brazilian Jiu-Jitsu',
#  'Stephen Thompson': 'Upstate Karate Family Martial Arts Center',
#  'Geoff Neal': 'Fortis MMA',
#  'Joaquin Buckley': 'Freestyle',
#  'Neil Magny': 'Elevation Fight Team - Denver, CO',
#  'Vicente Luque': 'Blackzilians - Boca Raton, FL',
#  'Michael Page': '75.00',
#  'Kevin Holland': 'Kung Fu',
#  'Dricus Du Plessis': 'MMA',
#  'Sean Strickland': 'Millennia MMA, Rancho, CA',
#  'Israel Adesanya': 'City Kickboxing',
#  'Robert Whittaker': 'PMA, Padstow NSW, Australia',
#  'Nassourdine Imavov': 'Venum Training Camp Paris',
#  'Jared Cannonier': 'ABJJ + Gracie Barra Alaska',
#  'Marvin Vettori': 'Kings MMA - Huntington Beach, CA',
#  'Brendan Allen': 'Kill Cliff FC',
#  'Paulo Costa': 'Team Borracha',
#  'Jack Hermansson': 'Frontline Academy - Oslo',
#  'Roman Dolidze': 'Xtreme Couture - Las Vegas, NV',
#  'Khamzat Chimaev': '74.00',
#  'Caio Borralho': 'Combat Club',
#  'Michel Pereira': 'Overcome Academy',
#  'Anthony Hernandez': 'Striker',
#  'Chris Curtis': 'Xtreme Couture - Las Vegas, NV',
#  'Alex Pereira': 'Teixeira MMA & Fitness-Bethel, CT',
#  'Jiří Procházka': 'JETSAAM GYM',
#  'Magomed Ankalaev': 'MMA',
#  'Jamahal Hill': 'MMA',
#  'Jan Błachowicz': 'Gym information not found',
#  'Aleksandar Rakić': 'American Top Team Zagreb',
#  'Nikita Krylov': 'Karate',
#  'Volkan Oezdemir': 'Allstars Training Center',
#  'Khalil Rountree Jr.': 'Syndicate MMA - Las Vegas, NV',
#  'Johnny Walker': 'SBG Ireland',
#  'Carlos Ulberg': 'City Kickboxing',
#  'Anthony Smith': "Mick Doyle's Kickboxing - Omaha, NE",
#  'Bogdan Guskov': 'MMA',
#  'Dominick Reyes': 'Teixeira MMA & Fitness-Bethel, CT',
#  'Azamat Murzakanov': 'MMA',
#  'Alonzo Menifield': 'Freestyle',
#  'Jon Jones': '35',
#  'Tom Aspinall': 'Team Kaobon',
#  'Ciryl Gane': 'MMA Factory - Paris, France',
#  'Alexander Volkov': 'Global Fight Gym',
#  'Sergei Pavlovich': 'MMA',
#  'Curtis Blaydes': 'Dutch Style MMA/ UFC Gym Lombard IL',
#  'Stipe Miocic': 'Strongstyle Fight Team',
#  'Jailton Almeida': 'Boxing',
#  'Marcin Tybura': 'S4 Warszawa',
#  'Serghei Spivac': 'Polar Bear Team',
#  'Tai Tuivasa': 'Team Tuivasa',
#  'Derrick Lewis': '4oz Fight Club',
#  'Jairzinho Rozenstruik': 'American Top Team',
#  'Alexandr Romanov': 'Wrestler',
#  'Marcos Rogerio de Lima': '011 MMA TEAM',
#  'Rodrigo Nascimento': 'American Top Team',
#  'Alexa Grasso': 'Lobo Gym MMA',
#  'Zhang Weili': 'Muay Thai',
#  'Valentina Shevchenko': 'Tiger Muay Thai - Phuket, Thailand',
#  'Manon Fiorot': 'Karate',
#  'Julianna Peña': 'Sik-Jitsu Spokane, WA',
#  'Raquel Pennington': 'Colorado Springs BJJ',
#  'Rose Namajunas': 'Grudge Training Center',
#  'Erin Blanchfield': 'Jiu-Jitsu',
#  'Tatiana Suarez': 'Millennia MMA - Rancho Cucamonga, CA',
#  'Yan Xiaonan': 'China Top Team Beijing',
#  'Jéssica Andrade': 'PRVT Para Vale Tudo',
#  'Kayla Harrison': 'Judo',
#  'Virna Jandiroba': 'Jiu-Jitsu',
#  'Ketlen Vieira': 'Judo',
#  'Amanda Lemos': 'Marajo Brothers',
#  'Marina Rodriguez': 'Muay Thai',
#  'Mackenzie Dern': 'Megaton Dias BJJ',
#  'Amanda Ribas': 'Judo',
#  'Angela Hill': 'Muay Thai',
#  'Loopy Godinez': '30',
#  'Tabatha Ricci': 'Judo',
#  'Luana Pinheiro': 'Judo',
#  'Gillian Robertson': 'MMA',
#  'Iasmin Lucindo': 'Striker',
#  'Karolina Kowalkiewicz': 'Gracie Barra Lodz',
#  'Maycee Barber': 'Team Alpha Male',
#  'Katlyn Cerminara': 'Renzo Gracie Academy',
#  'Natalia Silva': 'Taekwondo',
#  'Viviane Araújo': 'MMA',
#  'Karine Silva': 'Gile Ribeiro - Curitiba, Brazil',
#  'Tracy Cortez': 'MMA',
#  'Ariane da Silva': 'Gym information not found',
#  'Jasmine Jasudavicius': 'Niagara Top Team',
#  "Casey O'Neill": 'Gym information not found',
#  'Irene Aldana': 'Striker',
#  'Macy Chiasson': 'Fortis MMA',
#  'Mayra Bueno Silva': 'Striker',
#  'Holly Holm': 'Joel Diaz Boxing',
#  'Karol Rosa': 'Muay Thai',
#  'Miesha Tate': 'Xtreme Couture - Las Vegas, NV',
#  'Norma Dumont': '33',
#  'Pannie Kianzad': 'MMA',
#  'Yana Santos': 'American Top Team',
#  'Julia Avila': '36',
#  'Chelsea Chandler': 'MMA',
#  'Germaine de Randamie': 'Team Germaine- csa Holland'}

# %%
for weight_class, fighters in rankings.items():
    print(weight_class, fighters)
# Out:
# Flyweight {'Champion': 'Alexandre Pantoja', '1': 'Brandon Royval', '2': 'Brandon Moreno', '3': 'Amir Albazi', '4': 'Kai Kara-France', '5': 'Tatsuro Taira', '6': 'Alex Perez', '7': 'Steve Erceg', '8': 'Matheus Nicolau', '9': 'Manel Kape', '10': 'Tim Elliott', '11': 'Matt Schnell', '12': 'Tagir Ulanbekov', '13': 'Bruno Silva', '14': 'Asu Almabayev', '15': 'Cody Durden'}
# Bantamweight {'Champion': "Sean O'Malley", '1': 'Merab Dvalishvili', '2': 'Cory Sandhagen', '3': 'Petr Yan', '4': 'Marlon Vera', '5': 'Henry Cejudo', '6': 'Deiveson Figueiredo', '7': 'Song Yadong', '8': 'José Aldo', '9': 'Rob Font', '10': 'Umar Nurmagomedov', '11': 'Kyler Phillips', '12': 'Mario Bautista', '13': 'Dominick Cruz', '14': 'Jonathan Martinez', '15': 'Montel Jackson'}
# Featherweight {'Champion': 'Ilia Topuria', '1': 'Alexander Volkanovski', '2': 'Max Holloway', '3': 'Brian Ortega', '4': 'Yair Rodriguez', '5': 'Arnold Allen', '7': 'Josh Emmett', '8': 'Aljamain Sterling', '9': 'Calvin Kattar', '10': 'Giga Chikadze', '11': 'Lerone Murphy', '12': 'Diego Lopes', '13': 'Bryce Mitchell', '14': 'Dan Ige', '15': 'Edson Barboza'}
# Lightweight {'Champion': 'Islam Makhachev', '1': 'Arman Tsarukyan', '2': 'Charles Oliveira', '3': 'Justin Gaethje', '4': 'Dustin Poirier', '5': 'Mateusz Gamrot', '6': 'Michael Chandler', '7': 'Beneil Dariush', '8': 'Rafael Fiziev', '9': 'Max Holloway', '10': 'Renato Moicano', '11': 'Dan Hooker', '12': 'Benoît Saint Denis', '13': 'Jalin Turner', '14': 'Rafael Dos Anjos', '15': 'Paddy Pimblett'}
# Welterweight {'Champion': 'Belal Muhammad', '1': 'Leon Edwards', '2': 'Kamaru Usman', '3': 'Shavkat Rakhmonov', '4': 'Colby Covington', '5': 'Jack Della Maddalena', '6': 'Gilbert Burns', '7': 'Ian Machado Garry', '8': 'Sean Brady', '9': 'Stephen Thompson', '10': 'Geoff Neal', '11': 'Joaquin Buckley', '12': 'Neil Magny', '13': 'Vicente Luque', '14': 'Michael Page', '15': 'Kevin Holland'}
# Middleweight {'Champion': 'Dricus Du Plessis', '1': 'Sean Strickland', '2': 'Israel Adesanya', '3': 'Robert Whittaker', '4': 'Nassourdine Imavov', '5': 'Jared Cannonier', '6': 'Marvin Vettori', '7': 'Brendan Allen', '8': 'Paulo Costa', '9': 'Jack Hermansson', '10': 'Roman Dolidze', '11': 'Khamzat Chimaev', '12': 'Caio Borralho', '13': 'Michel Pereira', '14': 'Anthony Hernandez', '15': 'Chris Curtis'}
# Light Heavyweight {'Champion': 'Alex Pereira', '1': 'Jiří Procházka', '2': 'Magomed Ankalaev', '3': 'Jamahal Hill', '4': 'Jan Błachowicz', '5': 'Aleksandar Rakić', '6': 'Nikita Krylov', '7': 'Volkan Oezdemir', '8': 'Khalil Rountree Jr.', '9': 'Johnny Walker', '10': 'Carlos Ulberg', '11': 'Anthony Smith', '12': 'Bogdan Guskov', '13': 'Dominick Reyes', '14': 'Azamat Murzakanov', '15': 'Alonzo Menifield'}
# Heavyweight {'Champion': 'Jon Jones', '1': 'Tom Aspinall', '2': 'Ciryl Gane', '3': 'Alexander Volkov', '4': 'Sergei Pavlovich', '5': 'Curtis Blaydes', '6': 'Stipe Miocic', '7': 'Jailton Almeida', '8': 'Marcin Tybura', '9': 'Serghei Spivac', '10': 'Tai Tuivasa', '11': 'Derrick Lewis', '12': 'Jairzinho Rozenstruik', '13': 'Alexandr Romanov', '14': 'Marcos Rogerio de Lima', '15': 'Rodrigo Nascimento'}
# Women's Pound-for-Pound Top Rank {'Champion': 'Alexa Grasso', '1': 'Alexa Grasso', '2': 'Zhang Weili', '3': 'Valentina Shevchenko', '4': 'Manon Fiorot', '5': 'Julianna Peña', '6': 'Raquel Pennington', '7': 'Rose Namajunas', '8': 'Erin Blanchfield', '9': 'Tatiana Suarez', '10': 'Yan Xiaonan', '11': 'Jéssica Andrade', '12': 'Kayla Harrison', '13': 'Virna Jandiroba', '14': 'Ketlen Vieira', '15': 'Amanda Lemos'}
# Women's Strawweight {'Champion': 'Zhang Weili', '1': 'Tatiana Suarez', '2': 'Yan Xiaonan', '3': 'Virna Jandiroba', '4': 'Jéssica Andrade', '5': 'Amanda Lemos', '6': 'Marina Rodriguez', '7': 'Mackenzie Dern', '8': 'Amanda Ribas', '9': 'Angela Hill', '10': 'Loopy Godinez', '11': 'Tabatha Ricci', '12': 'Luana Pinheiro', '13': 'Gillian Robertson', '14': 'Iasmin Lucindo', '15': 'Karolina Kowalkiewicz'}
# Women's Flyweight {'Champion': 'Alexa Grasso', '1': 'Valentina Shevchenko', '2': 'Manon Fiorot', '3': 'Erin Blanchfield', '4': 'Maycee Barber', '5': 'Rose Namajunas', '6': 'Jéssica Andrade', '7': 'Katlyn Cerminara', '8': 'Natalia Silva', '9': 'Amanda Ribas', '10': 'Viviane Araújo', '11': 'Karine Silva', '12': 'Tracy Cortez', '13': 'Ariane da Silva', '14': 'Jasmine Jasudavicius', '15': "Casey O'Neill"}
# Women's Bantamweight {'Champion': 'Raquel Pennington', '1': 'Julianna Peña', '2': 'Ketlen Vieira', '3': 'Kayla Harrison', '4': 'Irene Aldana', '5': 'Macy Chiasson', '6': 'Mayra Bueno Silva', '7': 'Holly Holm', '8': 'Karol Rosa', '9': 'Miesha Tate', '10': 'Norma Dumont', '11': 'Pannie Kianzad', '12': 'Yana Santos', '13': 'Julia Avila', '14': 'Chelsea Chandler', '15': 'Germaine de Randamie'}

# %%
import requests
from urllib.parse import quote
import time

# Replace 'YOUR_MAPBOX_ACCESS_TOKEN' with your actual Mapbox access token
ACCESS_TOKEN = 'pk.eyJ1IjoiYnJldHR6aW0iLCJhIjoiY2x6OTc0ZDBuMDRkaDJqcG40d3g1anE4aiJ9.XQvs8Hg7pOcp6FiIsG_PgQ'

def geocode_location_mapbox(location):
    # URL encode the location string
    encoded_location = quote(location)
    
    # Define the Mapbox Geocoding URL
    url = 'https://api.mapbox.com/geocoding/v5/mapbox.places/{}.json'.format(encoded_location)
    params = {
        'access_token': ACCESS_TOKEN,
        'limit': 1
    }

    response = requests.get(url, params=params)
    
    # Check if the response is valid
    if response.status_code == 200:
        try:
            data = response.json()
            if data['features']:
                # Extract latitude and longitude
                lat = data['features'][0]['geometry']['coordinates'][1]
                lon = data['features'][0]['geometry']['coordinates'][0]
                return lat, lon
            else:
                print(f"No results found for '{location}'")
        except ValueError:
            print("Error decoding JSON response")
    else:
        print(f"HTTP Error: {response.status_code}")
    
    return None, None

# Update rankings dictionary with gym locations and geocoded coordinates
for weight_class, athletes in rankings.items():
    print(f"Processing weight class: {weight_class}")
    for rank, athlete in athletes.items():
        gym_location = fighter_gym_dict.get(athlete)
        if gym_location:
            print(f"Geocoding gym location for {athlete}: {gym_location}")
            lat, lon = geocode_location_mapbox(gym_location)
            if lat and lon:
                # Add geocoded location to the dictionary
                rankings[weight_class][rank] = {
                    'name': athlete,
                    'gym_location': gym_location,
                    'latitude': lat,
                    'longitude': lon
                }
            else:
                # If geocoding fails, just add the name
                rankings[weight_class][rank] = {
                    'name': athlete,
                    'gym_location': gym_location,
                    'latitude': None,
                    'longitude': None
                }
            # Add a delay to avoid hitting rate limits
            time.sleep(2)
# Out:
# Processing weight class: Flyweight
# Geocoding gym location for Alexandre Pantoja: American Top Team
# Geocoding gym location for Brandon Royval: Factory X
# Geocoding gym location for Brandon Moreno: Jiu-Jitsu
# Geocoding gym location for Amir Albazi: Xtreme Couture - Las Vegas, NV
# Geocoding gym location for Kai Kara-France: City Kickboxing
# Geocoding gym location for Tatsuro Taira: 24
# Geocoding gym location for Alex Perez: Syndicate MMA
# Geocoding gym location for Steve Erceg: MMA
# Geocoding gym location for Matheus Nicolau: Nova Uniao - Rio de Janeiro
# Geocoding gym location for Manel Kape: Xtreme Couture - Las Vegas, NV
# Geocoding gym location for Tim Elliott: Freestyle
# Geocoding gym location for Matt Schnell: Boxing
# Geocoding gym location for Tagir Ulanbekov: Eagles MMA Team
# Geocoding gym location for Bruno Silva: Grappler
# Geocoding gym location for Asu Almabayev: Gym information not found
# Geocoding gym location for Cody Durden: American Top Team
# Processing weight class: Bantamweight
# Geocoding gym location for Sean O'Malley: MMA LAB - Glendale, AZ
# Geocoding gym location for Merab Dvalishvili: Team Serra/Longo
# Geocoding gym location for Cory Sandhagen: MMA
# Geocoding gym location for Petr Yan: Team Yan
# Geocoding gym location for Marlon Vera: Grappler
# Geocoding gym location for Henry Cejudo: Fight Ready - Scottsdale, AZ
# Geocoding gym location for Deiveson Figueiredo: Team Figueiredo
# Geocoding gym location for Song Yadong: Team Alpha Male
# Geocoding gym location for José Aldo: Nova União
# Geocoding gym location for Rob Font: Sityodtong - Boston
# Geocoding gym location for Umar Nurmagomedov: MMA
# Geocoding gym location for Kyler Phillips: The MMA Lab
# Geocoding gym location for Mario Bautista: The MMA Lab
# Geocoding gym location for Dominick Cruz: Alliance Training Center East -Santee
# Geocoding gym location for Jonathan Martinez: Factory X
# Geocoding gym location for Montel Jackson: Pura Vida BJJ & MMA
# Processing weight class: Featherweight
# Geocoding gym location for Ilia Topuria: Brazilian Jiu-Jitsu
# Geocoding gym location for Alexander Volkanovski: Freestyle Fighting Gym
# Geocoding gym location for Max Holloway: Hawaii Elite MMA - Hawaii
# Geocoding gym location for Brian Ortega: Team Ortega
# Geocoding gym location for Yair Rodriguez: Izzystyle wrestling & VFS Chicago
# Geocoding gym location for Arnold Allen: BKK / Tristar
# Geocoding gym location for Josh Emmett: Team Alpha Male  (Urijah Faber's Ultimate Fitness)
# Geocoding gym location for Aljamain Sterling: Serra-Longo - Long Island, NY
# Geocoding gym location for Calvin Kattar: New England MMA
# Geocoding gym location for Giga Chikadze: Kings MMA
# Geocoding gym location for Lerone Murphy: All Powers Gym
# Geocoding gym location for Diego Lopes: Jiu-Jitsu
# Geocoding gym location for Bryce Mitchell: MMA
# Geocoding gym location for Dan Ige: Jiu-Jitsu
# Geocoding gym location for Edson Barboza: Ricardo Almeida / Valor MMA
# Processing weight class: Lightweight
# Geocoding gym location for Islam Makhachev: AKA (American Kickboxing Academy) San Jose
# Geocoding gym location for Arman Tsarukyan: Syndicate MMA - Las Vegas, NV
# Geocoding gym location for Charles Oliveira: Bronx's Gold Team
# Geocoding gym location for Justin Gaethje: Genesis Training Center
# Geocoding gym location for Dustin Poirier: American Top Team ATT Coconut Creek, FL
# Geocoding gym location for Mateusz Gamrot: American Top Team
# Geocoding gym location for Michael Chandler: Sanford MMA
# Geocoding gym location for Beneil Dariush: Kings MMA - Huntington Beach, CA
# Geocoding gym location for Rafael Fiziev: Tiger Muay Thai - Phuket, Thailand
# Geocoding gym location for Max Holloway: Hawaii Elite MMA - Hawaii
# Geocoding gym location for Renato Moicano: American Top Team
# Geocoding gym location for Dan Hooker: Saigon Sports Club- Vietnam
# Geocoding gym location for Benoît Saint Denis: Venum Training Camp Paris
# Geocoding gym location for Jalin Turner: MMA
# Geocoding gym location for Rafael Dos Anjos: Kings MMA - Huntington Beach, CA
# Geocoding gym location for Paddy Pimblett: NEXT Generation MMA
# Processing weight class: Welterweight
# Geocoding gym location for Belal Muhammad: Roufusport, (Mikwaukee, WI) & Chicago Fight Team (Chicago, IL)
# Geocoding gym location for Leon Edwards: UTC Ultimate Training Centre Birmingham
# Geocoding gym location for Kamaru Usman: Blackzilians - Boca Raton, FL
# Geocoding gym location for Shavkat Rakhmonov: Kill Cliff FC
# Geocoding gym location for Colby Covington: MMA Masters - Miami, FL
# Geocoding gym location for Jack Della Maddalena: MMA
# Geocoding gym location for Gilbert Burns: Jaco Hybrid Training Center
# Geocoding gym location for Ian Machado Garry: Gym information not found
# Geocoding gym location for Sean Brady: Brazilian Jiu-Jitsu
# Geocoding gym location for Stephen Thompson: Upstate Karate Family Martial Arts Center
# Geocoding gym location for Geoff Neal: Fortis MMA
# Geocoding gym location for Joaquin Buckley: Freestyle
# Geocoding gym location for Neil Magny: Elevation Fight Team - Denver, CO
# Geocoding gym location for Vicente Luque: Blackzilians - Boca Raton, FL
# Geocoding gym location for Michael Page: 75.00
# Geocoding gym location for Kevin Holland: Kung Fu
# Processing weight class: Middleweight
# Geocoding gym location for Dricus Du Plessis: MMA
# Geocoding gym location for Sean Strickland: Millennia MMA, Rancho, CA
# Geocoding gym location for Israel Adesanya: City Kickboxing
# Geocoding gym location for Robert Whittaker: PMA, Padstow NSW, Australia
# Geocoding gym location for Nassourdine Imavov: Venum Training Camp Paris
# Geocoding gym location for Jared Cannonier: ABJJ + Gracie Barra Alaska
# Geocoding gym location for Marvin Vettori: Kings MMA - Huntington Beach, CA
# Geocoding gym location for Brendan Allen: Kill Cliff FC
# Geocoding gym location for Paulo Costa: Team Borracha
# Geocoding gym location for Jack Hermansson: Frontline Academy - Oslo
# Geocoding gym location for Roman Dolidze: Xtreme Couture - Las Vegas, NV
# Geocoding gym location for Khamzat Chimaev: 74.00
# Geocoding gym location for Caio Borralho: Combat Club
# Geocoding gym location for Michel Pereira: Overcome Academy
# Geocoding gym location for Anthony Hernandez: Striker
# Geocoding gym location for Chris Curtis: Xtreme Couture - Las Vegas, NV
# Processing weight class: Light Heavyweight
# Geocoding gym location for Alex Pereira: Teixeira MMA & Fitness-Bethel, CT
# Geocoding gym location for Jiří Procházka: JETSAAM GYM
# Geocoding gym location for Magomed Ankalaev: MMA
# Geocoding gym location for Jamahal Hill: MMA
# Geocoding gym location for Jan Błachowicz: Gym information not found
# Geocoding gym location for Aleksandar Rakić: American Top Team Zagreb
# Geocoding gym location for Nikita Krylov: Karate
# Geocoding gym location for Volkan Oezdemir: Allstars Training Center
# Geocoding gym location for Khalil Rountree Jr.: Syndicate MMA - Las Vegas, NV
# Geocoding gym location for Johnny Walker: SBG Ireland
# Geocoding gym location for Carlos Ulberg: City Kickboxing
# Geocoding gym location for Anthony Smith: Mick Doyle's Kickboxing - Omaha, NE
# Geocoding gym location for Bogdan Guskov: MMA
# Geocoding gym location for Dominick Reyes: Teixeira MMA & Fitness-Bethel, CT
# Geocoding gym location for Azamat Murzakanov: MMA
# Geocoding gym location for Alonzo Menifield: Freestyle
# Processing weight class: Heavyweight
# Geocoding gym location for Jon Jones: 35
# Geocoding gym location for Tom Aspinall: Team Kaobon
# Geocoding gym location for Ciryl Gane: MMA Factory - Paris, France
# Geocoding gym location for Alexander Volkov: Global Fight Gym
# Geocoding gym location for Sergei Pavlovich: MMA
# Geocoding gym location for Curtis Blaydes: Dutch Style MMA/ UFC Gym Lombard IL
# Geocoding gym location for Stipe Miocic: Strongstyle Fight Team
# Geocoding gym location for Jailton Almeida: Boxing
# Geocoding gym location for Marcin Tybura: S4 Warszawa
# Geocoding gym location for Serghei Spivac: Polar Bear Team
# Geocoding gym location for Tai Tuivasa: Team Tuivasa
# Geocoding gym location for Derrick Lewis: 4oz Fight Club
# Geocoding gym location for Jairzinho Rozenstruik: American Top Team
# Geocoding gym location for Alexandr Romanov: Wrestler
# Geocoding gym location for Marcos Rogerio de Lima: 011 MMA TEAM
# Geocoding gym location for Rodrigo Nascimento: American Top Team
# Processing weight class: Women's Pound-for-Pound Top Rank
# Geocoding gym location for Alexa Grasso: Lobo Gym MMA
# Geocoding gym location for Alexa Grasso: Lobo Gym MMA
# Geocoding gym location for Zhang Weili: Muay Thai
# Geocoding gym location for Valentina Shevchenko: Tiger Muay Thai - Phuket, Thailand
# Geocoding gym location for Manon Fiorot: Karate
# Geocoding gym location for Julianna Peña: Sik-Jitsu Spokane, WA
# Geocoding gym location for Raquel Pennington: Colorado Springs BJJ
# Geocoding gym location for Rose Namajunas: Grudge Training Center
# Geocoding gym location for Erin Blanchfield: Jiu-Jitsu
# Geocoding gym location for Tatiana Suarez: Millennia MMA - Rancho Cucamonga, CA
# Geocoding gym location for Yan Xiaonan: China Top Team Beijing
# Geocoding gym location for Jéssica Andrade: PRVT Para Vale Tudo
# Geocoding gym location for Kayla Harrison: Judo
# Geocoding gym location for Virna Jandiroba: Jiu-Jitsu
# Geocoding gym location for Ketlen Vieira: Judo
# Geocoding gym location for Amanda Lemos: Marajo Brothers
# Processing weight class: Women's Strawweight
# Geocoding gym location for Zhang Weili: Muay Thai
# Geocoding gym location for Tatiana Suarez: Millennia MMA - Rancho Cucamonga, CA
# Geocoding gym location for Yan Xiaonan: China Top Team Beijing
# Geocoding gym location for Virna Jandiroba: Jiu-Jitsu
# Geocoding gym location for Jéssica Andrade: PRVT Para Vale Tudo
# Geocoding gym location for Amanda Lemos: Marajo Brothers
# Geocoding gym location for Marina Rodriguez: Muay Thai
# Geocoding gym location for Mackenzie Dern: Megaton Dias BJJ
# Geocoding gym location for Amanda Ribas: Judo
# Geocoding gym location for Angela Hill: Muay Thai
# Geocoding gym location for Loopy Godinez: 30
# Geocoding gym location for Tabatha Ricci: Judo
# Geocoding gym location for Luana Pinheiro: Judo
# Geocoding gym location for Gillian Robertson: MMA
# Geocoding gym location for Iasmin Lucindo: Striker
# Geocoding gym location for Karolina Kowalkiewicz: Gracie Barra Lodz
# Processing weight class: Women's Flyweight
# Geocoding gym location for Alexa Grasso: Lobo Gym MMA
# Geocoding gym location for Valentina Shevchenko: Tiger Muay Thai - Phuket, Thailand
# Geocoding gym location for Manon Fiorot: Karate
# Geocoding gym location for Erin Blanchfield: Jiu-Jitsu
# Geocoding gym location for Maycee Barber: Team Alpha Male
# Geocoding gym location for Rose Namajunas: Grudge Training Center
# Geocoding gym location for Jéssica Andrade: PRVT Para Vale Tudo
# Geocoding gym location for Katlyn Cerminara: Renzo Gracie Academy
# Geocoding gym location for Natalia Silva: Taekwondo
# Geocoding gym location for Amanda Ribas: Judo
# Geocoding gym location for Viviane Araújo: MMA
# Geocoding gym location for Karine Silva: Gile Ribeiro - Curitiba, Brazil
# Geocoding gym location for Tracy Cortez: MMA
# Geocoding gym location for Ariane da Silva: Gym information not found
# Geocoding gym location for Jasmine Jasudavicius: Niagara Top Team
# Geocoding gym location for Casey O'Neill: Gym information not found
# Processing weight class: Women's Bantamweight
# Geocoding gym location for Raquel Pennington: Colorado Springs BJJ
# Geocoding gym location for Julianna Peña: Sik-Jitsu Spokane, WA
# Geocoding gym location for Ketlen Vieira: Judo
# Geocoding gym location for Kayla Harrison: Judo
# Geocoding gym location for Irene Aldana: Striker
# Geocoding gym location for Macy Chiasson: Fortis MMA
# Geocoding gym location for Mayra Bueno Silva: Striker
# Geocoding gym location for Holly Holm: Joel Diaz Boxing
# Geocoding gym location for Karol Rosa: Muay Thai
# Geocoding gym location for Miesha Tate: Xtreme Couture - Las Vegas, NV
# Geocoding gym location for Norma Dumont: 33
# Geocoding gym location for Pannie Kianzad: MMA
# Geocoding gym location for Yana Santos: American Top Team
# Geocoding gym location for Julia Avila: 36
# Geocoding gym location for Chelsea Chandler: MMA
# Geocoding gym location for Germaine de Randamie: Team Germaine- csa Holland
# Updated Rankings with Geocoded Locations:
# Weight Class: Flyweight
# Rank Champion: {'name': 'Alexandre Pantoja', 'gym_location': 'American Top Team', 'latitude': 41.401486, 'longitude': -73.431107}
# Rank 1: {'name': 'Brandon Royval', 'gym_location': 'Factory X', 'latitude': 36.239573, 'longitude': 36.177717}
# Rank 2: {'name': 'Brandon Moreno', 'gym_location': 'Jiu-Jitsu', 'latitude': 41.003537, 'longitude': -73.663302}
# Rank 3: {'name': 'Amir Albazi', 'gym_location': 'Xtreme Couture - Las Vegas, NV', 'latitude': 36.226171, 'longitude': -115.323575}
# Rank 4: {'name': 'Kai Kara-France', 'gym_location': 'City Kickboxing', 'latitude': -36.865604, 'longitude': 174.75294}
# Rank 5: {'name': 'Tatsuro Taira', 'gym_location': '24', 'latitude': 4.218998, 'longitude': 103.423598}
# Rank 6: {'name': 'Alex Perez', 'gym_location': 'Syndicate MMA', 'latitude': 36.056956, 'longitude': -115.245147}
# Rank 7: {'name': 'Steve Erceg', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 8: {'name': 'Matheus Nicolau', 'gym_location': 'Nova Uniao - Rio de Janeiro', 'latitude': -22.936483, 'longitude': -43.1776715}
# Rank 9: {'name': 'Manel Kape', 'gym_location': 'Xtreme Couture - Las Vegas, NV', 'latitude': 36.226171, 'longitude': -115.323575}
# Rank 10: {'name': 'Tim Elliott', 'gym_location': 'Freestyle', 'latitude': 44.809144, 'longitude': 20.445516}
# Rank 11: {'name': 'Matt Schnell', 'gym_location': 'Boxing', 'latitude': 31.212586, 'longitude': 121.438435}
# Rank 12: {'name': 'Tagir Ulanbekov', 'gym_location': 'Eagles MMA Team', 'latitude': 43.63531, 'longitude': -116.43321}
# Rank 13: {'name': 'Bruno Silva', 'gym_location': 'Grappler', 'latitude': 39.74047, 'longitude': -104.92551}
# Rank 14: {'name': 'Asu Almabayev', 'gym_location': 'Gym information not found', 'latitude': 45.096305, 'longitude': -93.379213}
# Rank 15: {'name': 'Cody Durden', 'gym_location': 'American Top Team', 'latitude': 41.401486, 'longitude': -73.431107}
# Weight Class: Bantamweight
# Rank Champion: {'name': "Sean O'Malley", 'gym_location': 'MMA LAB - Glendale, AZ', 'latitude': 33.53855, 'longitude': -112.18309}
# Rank 1: {'name': 'Merab Dvalishvili', 'gym_location': 'Team Serra/Longo', 'latitude': 39.43218, 'longitude': 16.36962}
# Rank 2: {'name': 'Cory Sandhagen', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 3: {'name': 'Petr Yan', 'gym_location': 'Team Yan', 'latitude': -7.224538, 'longitude': -35.88803}
# Rank 4: {'name': 'Marlon Vera', 'gym_location': 'Grappler', 'latitude': 39.74047, 'longitude': -104.92551}
# Rank 5: {'name': 'Henry Cejudo', 'gym_location': 'Fight Ready - Scottsdale, AZ', 'latitude': 33.496822, 'longitude': -111.92618}
# Rank 6: {'name': 'Deiveson Figueiredo', 'gym_location': 'Team Figueiredo', 'latitude': 41.710492, 'longitude': -70.742356}
# Rank 7: {'name': 'Song Yadong', 'gym_location': 'Team Alpha Male', 'latitude': 2.182126, 'longitude': 102.26126}
# Rank 8: {'name': 'José Aldo', 'gym_location': 'Nova União', 'latitude': -19.689968, 'longitude': -43.57897}
# Rank 9: {'name': 'Rob Font', 'gym_location': 'Sityodtong - Boston', 'latitude': 42.35888, 'longitude': -71.0568}
# Rank 10: {'name': 'Umar Nurmagomedov', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 11: {'name': 'Kyler Phillips', 'gym_location': 'The MMA Lab', 'latitude': 46.775093, 'longitude': 6.28015}
# Rank 12: {'name': 'Mario Bautista', 'gym_location': 'The MMA Lab', 'latitude': 46.775093, 'longitude': 6.28015}
# Rank 13: {'name': 'Dominick Cruz', 'gym_location': 'Alliance Training Center East -Santee', 'latitude': 32.847002, 'longitude': -116.962258}
# Rank 14: {'name': 'Jonathan Martinez', 'gym_location': 'Factory X', 'latitude': 36.239573, 'longitude': 36.177717}
# Rank 15: {'name': 'Montel Jackson', 'gym_location': 'Pura Vida BJJ & MMA', 'latitude': 47.587067, 'longitude': 7.566089}
# Weight Class: Featherweight
# Rank Champion: {'name': 'Ilia Topuria', 'gym_location': 'Brazilian Jiu-Jitsu', 'latitude': 40.096742, 'longitude': -75.125668}
# Rank 1: {'name': 'Alexander Volkanovski', 'gym_location': 'Freestyle Fighting Gym', 'latitude': 40.965341, 'longitude': 29.074235}
# Rank 2: {'name': 'Max Holloway', 'gym_location': 'Hawaii Elite MMA - Hawaii', 'latitude': 19.951097, 'longitude': -155.860178}
# Rank 3: {'name': 'Brian Ortega', 'gym_location': 'Team Ortega', 'latitude': 37.344871, 'longitude': -122.002382}
# Rank 4: {'name': 'Yair Rodriguez', 'gym_location': 'Izzystyle wrestling & VFS Chicago', 'latitude': -34.86904, 'longitude': -58.061008}
# Rank 5: {'name': 'Arnold Allen', 'gym_location': 'BKK / Tristar', 'latitude': 13.68970625, 'longitude': 100.75025550000001}
# Rank 7: {'name': 'Josh Emmett', 'gym_location': "Team Alpha Male  (Urijah Faber's Ultimate Fitness)", 'latitude': 0.9174313, 'longitude': 34.1578606}
# Rank 8: {'name': 'Aljamain Sterling', 'gym_location': 'Serra-Longo - Long Island, NY', 'latitude': 40.805805, 'longitude': -73.253616}
# Rank 9: {'name': 'Calvin Kattar', 'gym_location': 'New England MMA', 'latitude': 53.367321, 'longitude': -2.265102}
# Rank 10: {'name': 'Giga Chikadze', 'gym_location': 'Kings MMA', 'latitude': 33.7161, 'longitude': -117.999588}
# Rank 11: {'name': 'Lerone Murphy', 'gym_location': 'All Powers Gym', 'latitude': 42.908025, 'longitude': -112.45047}
# Rank 12: {'name': 'Diego Lopes', 'gym_location': 'Jiu-Jitsu', 'latitude': 41.003537, 'longitude': -73.663302}
# Rank 13: {'name': 'Bryce Mitchell', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 14: {'name': 'Dan Ige', 'gym_location': 'Jiu-Jitsu', 'latitude': 41.003537, 'longitude': -73.663302}
# Rank 15: {'name': 'Edson Barboza', 'gym_location': 'Ricardo Almeida / Valor MMA', 'latitude': -23.562981, 'longitude': -46.668756}
# Weight Class: Lightweight
# Rank Champion: {'name': 'Islam Makhachev', 'gym_location': 'AKA (American Kickboxing Academy) San Jose', 'latitude': 37.264671, 'longitude': -121.917046}
# Rank 1: {'name': 'Arman Tsarukyan', 'gym_location': 'Syndicate MMA - Las Vegas, NV', 'latitude': 36.057018, 'longitude': -115.244765}
# Rank 2: {'name': 'Charles Oliveira', 'gym_location': "Bronx's Gold Team", 'latitude': 40.711273, 'longitude': -74.202789}
# Rank 3: {'name': 'Justin Gaethje', 'gym_location': 'Genesis Training Center', 'latitude': 35.497055, 'longitude': -84.401413}
# Rank 4: {'name': 'Dustin Poirier', 'gym_location': 'American Top Team ATT Coconut Creek, FL', 'latitude': 26.297208, 'longitude': -80.202009}
# Rank 5: {'name': 'Mateusz Gamrot', 'gym_location': 'American Top Team', 'latitude': 41.401486, 'longitude': -73.431107}
# Rank 6: {'name': 'Michael Chandler', 'gym_location': 'Sanford MMA', 'latitude': 28.811337, 'longitude': -81.320173}
# Rank 7: {'name': 'Beneil Dariush', 'gym_location': 'Kings MMA - Huntington Beach, CA', 'latitude': 33.7161, 'longitude': -117.999588}
# Rank 8: {'name': 'Rafael Fiziev', 'gym_location': 'Tiger Muay Thai - Phuket, Thailand', 'latitude': 7.882835, 'longitude': 98.39086}
# Rank 9: {'name': 'Max Holloway', 'gym_location': 'Hawaii Elite MMA - Hawaii', 'latitude': 19.951097, 'longitude': -155.860178}
# Rank 10: {'name': 'Renato Moicano', 'gym_location': 'American Top Team', 'latitude': 41.401486, 'longitude': -73.431107}
# Rank 11: {'name': 'Dan Hooker', 'gym_location': 'Saigon Sports Club- Vietnam', 'latitude': 10.739537, 'longitude': 106.728993}
# Rank 12: {'name': 'Benoît Saint Denis', 'gym_location': 'Venum Training Camp Paris', 'latitude': 48.8534951, 'longitude': 2.3483915}
# Rank 13: {'name': 'Jalin Turner', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 14: {'name': 'Rafael Dos Anjos', 'gym_location': 'Kings MMA - Huntington Beach, CA', 'latitude': 33.7161, 'longitude': -117.999588}
# Rank 15: {'name': 'Paddy Pimblett', 'gym_location': 'NEXT Generation MMA', 'latitude': -36.853851, 'longitude': 174.773006}
# Weight Class: Welterweight
# Rank Champion: {'name': 'Belal Muhammad', 'gym_location': 'Roufusport, (Mikwaukee, WI) & Chicago Fight Team (Chicago, IL)', 'latitude': 41.884636, 'longitude': -88.2049}
# Rank 1: {'name': 'Leon Edwards', 'gym_location': 'UTC Ultimate Training Centre Birmingham', 'latitude': 40.760587, 'longitude': -73.973942}
# Rank 2: {'name': 'Kamaru Usman', 'gym_location': 'Blackzilians - Boca Raton, FL', 'latitude': 26.3709205, 'longitude': -80.102879}
# Rank 3: {'name': 'Shavkat Rakhmonov', 'gym_location': 'Kill Cliff FC', 'latitude': -36.927555, 'longitude': -73.030244}
# Rank 4: {'name': 'Colby Covington', 'gym_location': 'MMA Masters - Miami, FL', 'latitude': 25.790915, 'longitude': -80.194434}
# Rank 5: {'name': 'Jack Della Maddalena', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 6: {'name': 'Gilbert Burns', 'gym_location': 'Jaco Hybrid Training Center', 'latitude': 35.704535, 'longitude': 139.774374}
# Rank 7: {'name': 'Ian Machado Garry', 'gym_location': 'Gym information not found', 'latitude': 45.096305, 'longitude': -93.379213}
# Rank 8: {'name': 'Sean Brady', 'gym_location': 'Brazilian Jiu-Jitsu', 'latitude': 40.096742, 'longitude': -75.125668}
# Rank 9: {'name': 'Stephen Thompson', 'gym_location': 'Upstate Karate Family Martial Arts Center', 'latitude': 42.565902, 'longitude': -71.774926}
# Rank 10: {'name': 'Geoff Neal', 'gym_location': 'Fortis MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 11: {'name': 'Joaquin Buckley', 'gym_location': 'Freestyle', 'latitude': 44.809144, 'longitude': 20.445516}
# Rank 12: {'name': 'Neil Magny', 'gym_location': 'Elevation Fight Team - Denver, CO', 'latitude': 39.74001, 'longitude': -104.98613}
# Rank 13: {'name': 'Vicente Luque', 'gym_location': 'Blackzilians - Boca Raton, FL', 'latitude': 26.3709205, 'longitude': -80.102879}
# Rank 14: {'name': 'Michael Page', 'gym_location': '75.00', 'latitude': -33.423581, 'longitude': -70.612449}
# Rank 15: {'name': 'Kevin Holland', 'gym_location': 'Kung Fu', 'latitude': 40.74338, 'longitude': -73.825741}
# Weight Class: Middleweight
# Rank Champion: {'name': 'Dricus Du Plessis', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 1: {'name': 'Sean Strickland', 'gym_location': 'Millennia MMA, Rancho, CA', 'latitude': 34.100554, 'longitude': -117.545213}
# Rank 2: {'name': 'Israel Adesanya', 'gym_location': 'City Kickboxing', 'latitude': -36.865604, 'longitude': 174.75294}
# Rank 3: {'name': 'Robert Whittaker', 'gym_location': 'PMA, Padstow NSW, Australia', 'latitude': -33.948677, 'longitude': 151.029661}
# Rank 4: {'name': 'Nassourdine Imavov', 'gym_location': 'Venum Training Camp Paris', 'latitude': 48.8534951, 'longitude': 2.3483915}
# Rank 5: {'name': 'Jared Cannonier', 'gym_location': 'ABJJ + Gracie Barra Alaska', 'latitude': 64.6358675746153, 'longitude': -153.180996665583}
# Rank 6: {'name': 'Marvin Vettori', 'gym_location': 'Kings MMA - Huntington Beach, CA', 'latitude': 33.7161, 'longitude': -117.999588}
# Rank 7: {'name': 'Brendan Allen', 'gym_location': 'Kill Cliff FC', 'latitude': -36.927555, 'longitude': -73.030244}
# Rank 8: {'name': 'Paulo Costa', 'gym_location': 'Team Borracha', 'latitude': -13.011668, 'longitude': -38.490519}
# Rank 9: {'name': 'Jack Hermansson', 'gym_location': 'Frontline Academy - Oslo', 'latitude': 32.4131, 'longitude': -93.71859}
# Rank 10: {'name': 'Roman Dolidze', 'gym_location': 'Xtreme Couture - Las Vegas, NV', 'latitude': 36.226171, 'longitude': -115.323575}
# Rank 11: {'name': 'Khamzat Chimaev', 'gym_location': '74.00', 'latitude': 13.548154, 'longitude': 100.276836}
# Rank 12: {'name': 'Caio Borralho', 'gym_location': 'Combat Club', 'latitude': -23.530178, 'longitude': -46.659576}
# Rank 13: {'name': 'Michel Pereira', 'gym_location': 'Overcome Academy', 'latitude': 39.956826, 'longitude': -75.1714785}
# Rank 14: {'name': 'Anthony Hernandez', 'gym_location': 'Striker', 'latitude': 18.662557, 'longitude': -68.395309}
# Rank 15: {'name': 'Chris Curtis', 'gym_location': 'Xtreme Couture - Las Vegas, NV', 'latitude': 36.226171, 'longitude': -115.323575}
# Weight Class: Light Heavyweight
# Rank Champion: {'name': 'Alex Pereira', 'gym_location': 'Teixeira MMA & Fitness-Bethel, CT', 'latitude': 41.416771999999995, 'longitude': -73.390839}
# Rank 1: {'name': 'Jiří Procházka', 'gym_location': 'JETSAAM GYM', 'latitude': 40.965341, 'longitude': 29.074235}
# Rank 2: {'name': 'Magomed Ankalaev', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 3: {'name': 'Jamahal Hill', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 4: {'name': 'Jan Błachowicz', 'gym_location': 'Gym information not found', 'latitude': 45.096305, 'longitude': -93.379213}
# Rank 5: {'name': 'Aleksandar Rakić', 'gym_location': 'American Top Team Zagreb', 'latitude': 26.297208, 'longitude': -80.202009}
# Rank 6: {'name': 'Nikita Krylov', 'gym_location': 'Karate', 'latitude': 37.297172, 'longitude': 36.24992}
# Rank 7: {'name': 'Volkan Oezdemir', 'gym_location': 'Allstars Training Center', 'latitude': 59.34866, 'longitude': 18.048948}
# Rank 8: {'name': 'Khalil Rountree Jr.', 'gym_location': 'Syndicate MMA - Las Vegas, NV', 'latitude': 36.057018, 'longitude': -115.244765}
# Rank 9: {'name': 'Johnny Walker', 'gym_location': 'SBG Ireland', 'latitude': 53.912293500000004, 'longitude': -8.8148025}
# Rank 10: {'name': 'Carlos Ulberg', 'gym_location': 'City Kickboxing', 'latitude': -36.865604, 'longitude': 174.75294}
# Rank 11: {'name': 'Anthony Smith', 'gym_location': "Mick Doyle's Kickboxing - Omaha, NE", 'latitude': 41.257595, 'longitude': -95.934525}
# Rank 12: {'name': 'Bogdan Guskov', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 13: {'name': 'Dominick Reyes', 'gym_location': 'Teixeira MMA & Fitness-Bethel, CT', 'latitude': 41.416771999999995, 'longitude': -73.390839}
# Rank 14: {'name': 'Azamat Murzakanov', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 15: {'name': 'Alonzo Menifield', 'gym_location': 'Freestyle', 'latitude': 44.809144, 'longitude': 20.445516}
# Weight Class: Heavyweight
# Rank Champion: {'name': 'Jon Jones', 'gym_location': '35', 'latitude': 33.209826, 'longitude': -87.568225}
# Rank 1: {'name': 'Tom Aspinall', 'gym_location': 'Team Kaobon', 'latitude': 19.386111, 'longitude': -99.161754}
# Rank 2: {'name': 'Ciryl Gane', 'gym_location': 'MMA Factory - Paris, France', 'latitude': 48.868455, 'longitude': 2.283102}
# Rank 3: {'name': 'Alexander Volkov', 'gym_location': 'Global Fight Gym', 'latitude': 50.645261, 'longitude': -1.181197}
# Rank 4: {'name': 'Sergei Pavlovich', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 5: {'name': 'Curtis Blaydes', 'gym_location': 'Dutch Style MMA/ UFC Gym Lombard IL', 'latitude': 41.886932, 'longitude': -88.01974}
# Rank 6: {'name': 'Stipe Miocic', 'gym_location': 'Strongstyle Fight Team', 'latitude': 50.836905, 'longitude': -1.17521}
# Rank 7: {'name': 'Jailton Almeida', 'gym_location': 'Boxing', 'latitude': 31.212586, 'longitude': 121.438435}
# Rank 8: {'name': 'Marcin Tybura', 'gym_location': 'S4 Warszawa', 'latitude': 51.016884, 'longitude': 21.116658}
# Rank 9: {'name': 'Serghei Spivac', 'gym_location': 'Polar Bear Team', 'latitude': 34.144025, 'longitude': -83.985191}
# Rank 10: {'name': 'Tai Tuivasa', 'gym_location': 'Team Tuivasa', 'latitude': 19.386111, 'longitude': -99.161754}
# Rank 11: {'name': 'Derrick Lewis', 'gym_location': '4oz Fight Club', 'latitude': 44.416004, 'longitude': 8.715549}
# Rank 12: {'name': 'Jairzinho Rozenstruik', 'gym_location': 'American Top Team', 'latitude': 41.401486, 'longitude': -73.431107}
# Rank 13: {'name': 'Alexandr Romanov', 'gym_location': 'Wrestler', 'latitude': 51.770255, 'longitude': -0.217313}
# Rank 14: {'name': 'Marcos Rogerio de Lima', 'gym_location': '011 MMA TEAM', 'latitude': -23.572591, 'longitude': -46.642291}
# Rank 15: {'name': 'Rodrigo Nascimento', 'gym_location': 'American Top Team', 'latitude': 41.401486, 'longitude': -73.431107}
# Weight Class: Women's Pound-for-Pound Top Rank
# Rank Champion: {'name': 'Alexa Grasso', 'gym_location': 'Lobo Gym MMA', 'latitude': 39.730742, 'longitude': -104.968357}
# Rank 1: {'name': 'Alexa Grasso', 'gym_location': 'Lobo Gym MMA', 'latitude': 39.730742, 'longitude': -104.968357}
# Rank 2: {'name': 'Zhang Weili', 'gym_location': 'Muay Thai', 'latitude': 8.046092, 'longitude': 98.813206}
# Rank 3: {'name': 'Valentina Shevchenko', 'gym_location': 'Tiger Muay Thai - Phuket, Thailand', 'latitude': 7.882835, 'longitude': 98.39086}
# Rank 4: {'name': 'Manon Fiorot', 'gym_location': 'Karate', 'latitude': 37.297172, 'longitude': 36.24992}
# Rank 5: {'name': 'Julianna Peña', 'gym_location': 'Sik-Jitsu Spokane, WA', 'latitude': 47.65903, 'longitude': -117.42208}
# Rank 6: {'name': 'Raquel Pennington', 'gym_location': 'Colorado Springs BJJ', 'latitude': 39.60683, 'longitude': -105.940268}
# Rank 7: {'name': 'Rose Namajunas', 'gym_location': 'Grudge Training Center', 'latitude': 39.776285, 'longitude': -105.109354}
# Rank 8: {'name': 'Erin Blanchfield', 'gym_location': 'Jiu-Jitsu', 'latitude': 41.003537, 'longitude': -73.663302}
# Rank 9: {'name': 'Tatiana Suarez', 'gym_location': 'Millennia MMA - Rancho Cucamonga, CA', 'latitude': 34.100554, 'longitude': -117.545213}
# Rank 10: {'name': 'Yan Xiaonan', 'gym_location': 'China Top Team Beijing', 'latitude': 39.906217, 'longitude': 116.3912757}
# Rank 11: {'name': 'Jéssica Andrade', 'gym_location': 'PRVT Para Vale Tudo', 'latitude': -4.04612783594293, 'longitude': -53.1382861008915}
# Rank 12: {'name': 'Kayla Harrison', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 13: {'name': 'Virna Jandiroba', 'gym_location': 'Jiu-Jitsu', 'latitude': 41.003537, 'longitude': -73.663302}
# Rank 14: {'name': 'Ketlen Vieira', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 15: {'name': 'Amanda Lemos', 'gym_location': 'Marajo Brothers', 'latitude': 30.40204, 'longitude': -9.547788}
# Weight Class: Women's Strawweight
# Rank Champion: {'name': 'Zhang Weili', 'gym_location': 'Muay Thai', 'latitude': 8.046092, 'longitude': 98.813206}
# Rank 1: {'name': 'Tatiana Suarez', 'gym_location': 'Millennia MMA - Rancho Cucamonga, CA', 'latitude': 34.100554, 'longitude': -117.545213}
# Rank 2: {'name': 'Yan Xiaonan', 'gym_location': 'China Top Team Beijing', 'latitude': 39.906217, 'longitude': 116.3912757}
# Rank 3: {'name': 'Virna Jandiroba', 'gym_location': 'Jiu-Jitsu', 'latitude': 41.003537, 'longitude': -73.663302}
# Rank 4: {'name': 'Jéssica Andrade', 'gym_location': 'PRVT Para Vale Tudo', 'latitude': -4.04612783594293, 'longitude': -53.1382861008915}
# Rank 5: {'name': 'Amanda Lemos', 'gym_location': 'Marajo Brothers', 'latitude': 30.40204, 'longitude': -9.547788}
# Rank 6: {'name': 'Marina Rodriguez', 'gym_location': 'Muay Thai', 'latitude': 8.046092, 'longitude': 98.813206}
# Rank 7: {'name': 'Mackenzie Dern', 'gym_location': 'Megaton Dias BJJ', 'latitude': 40.21764, 'longitude': 28.825935}
# Rank 8: {'name': 'Amanda Ribas', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 9: {'name': 'Angela Hill', 'gym_location': 'Muay Thai', 'latitude': 8.046092, 'longitude': 98.813206}
# Rank 10: {'name': 'Loopy Godinez', 'gym_location': '30', 'latitude': 10.077764, 'longitude': -69.321993}
# Rank 11: {'name': 'Tabatha Ricci', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 12: {'name': 'Luana Pinheiro', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 13: {'name': 'Gillian Robertson', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 14: {'name': 'Iasmin Lucindo', 'gym_location': 'Striker', 'latitude': 18.662557, 'longitude': -68.395309}
# Rank 15: {'name': 'Karolina Kowalkiewicz', 'gym_location': 'Gracie Barra Lodz', 'latitude': 52.238667, 'longitude': 19.661135}
# Weight Class: Women's Flyweight
# Rank Champion: {'name': 'Alexa Grasso', 'gym_location': 'Lobo Gym MMA', 'latitude': 39.730742, 'longitude': -104.968357}
# Rank 1: {'name': 'Valentina Shevchenko', 'gym_location': 'Tiger Muay Thai - Phuket, Thailand', 'latitude': 7.882835, 'longitude': 98.39086}
# Rank 2: {'name': 'Manon Fiorot', 'gym_location': 'Karate', 'latitude': 37.297172, 'longitude': 36.24992}
# Rank 3: {'name': 'Erin Blanchfield', 'gym_location': 'Jiu-Jitsu', 'latitude': 41.003537, 'longitude': -73.663302}
# Rank 4: {'name': 'Maycee Barber', 'gym_location': 'Team Alpha Male', 'latitude': 2.182126, 'longitude': 102.26126}
# Rank 5: {'name': 'Rose Namajunas', 'gym_location': 'Grudge Training Center', 'latitude': 39.776285, 'longitude': -105.109354}
# Rank 6: {'name': 'Jéssica Andrade', 'gym_location': 'PRVT Para Vale Tudo', 'latitude': -4.04612783594293, 'longitude': -53.1382861008915}
# Rank 7: {'name': 'Katlyn Cerminara', 'gym_location': 'Renzo Gracie Academy', 'latitude': 40.748975, 'longitude': -73.993678}
# Rank 8: {'name': 'Natalia Silva', 'gym_location': 'Taekwondo', 'latitude': -23.504627, 'longitude': -46.623031}
# Rank 9: {'name': 'Amanda Ribas', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 10: {'name': 'Viviane Araújo', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 11: {'name': 'Karine Silva', 'gym_location': 'Gile Ribeiro - Curitiba, Brazil', 'latitude': -5.748406, 'longitude': -48.31669}
# Rank 12: {'name': 'Tracy Cortez', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 13: {'name': 'Ariane da Silva', 'gym_location': 'Gym information not found', 'latitude': 45.096305, 'longitude': -93.379213}
# Rank 14: {'name': 'Jasmine Jasudavicius', 'gym_location': 'Niagara Top Team', 'latitude': 43.669629, 'longitude': -79.386412}
# Rank 15: {'name': "Casey O'Neill", 'gym_location': 'Gym information not found', 'latitude': 45.096305, 'longitude': -93.379213}
# Weight Class: Women's Bantamweight
# Rank Champion: {'name': 'Raquel Pennington', 'gym_location': 'Colorado Springs BJJ', 'latitude': 39.60683, 'longitude': -105.940268}
# Rank 1: {'name': 'Julianna Peña', 'gym_location': 'Sik-Jitsu Spokane, WA', 'latitude': 47.65903, 'longitude': -117.42208}
# Rank 2: {'name': 'Ketlen Vieira', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 3: {'name': 'Kayla Harrison', 'gym_location': 'Judo', 'latitude': 37.82098, 'longitude': -122.260694}
# Rank 4: {'name': 'Irene Aldana', 'gym_location': 'Striker', 'latitude': 18.662557, 'longitude': -68.395309}
# Rank 5: {'name': 'Macy Chiasson', 'gym_location': 'Fortis MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 6: {'name': 'Mayra Bueno Silva', 'gym_location': 'Striker', 'latitude': 18.662557, 'longitude': -68.395309}
# Rank 7: {'name': 'Holly Holm', 'gym_location': 'Joel Diaz Boxing', 'latitude': 19.428492, 'longitude': -98.13104}
# Rank 8: {'name': 'Karol Rosa', 'gym_location': 'Muay Thai', 'latitude': 8.046092, 'longitude': 98.813206}
# Rank 9: {'name': 'Miesha Tate', 'gym_location': 'Xtreme Couture - Las Vegas, NV', 'latitude': 36.226171, 'longitude': -115.323575}
# Rank 10: {'name': 'Norma Dumont', 'gym_location': '33', 'latitude': 25.784059, 'longitude': -80.131015}
# Rank 11: {'name': 'Pannie Kianzad', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 12: {'name': 'Yana Santos', 'gym_location': 'American Top Team', 'latitude': 41.401486, 'longitude': -73.431107}
# Rank 13: {'name': 'Julia Avila', 'gym_location': '36', 'latitude': -1.617179, 'longitude': 103.592364}
# Rank 14: {'name': 'Chelsea Chandler', 'gym_location': 'MMA', 'latitude': -25.837608, 'longitude': 25.609612}
# Rank 15: {'name': 'Germaine de Randamie', 'gym_location': 'Team Germaine- csa Holland', 'latitude': 51.939472, 'longitude': 4.412035}

# %%
# Print updated rankings dictionary
print("Updated Rankings with Geocoded Locations:")
for weight_class, athletes in rankings.items():
    print(f"Weight Class: {weight_class}")
    for rank, details in athletes.items():
        print(f"Rank {rank}: {details}")

# %%
import json

# Your existing JSON data

# Convert to GeoJSON format
geojson = {
    "type": "FeatureCollection",
    "features": []
}

for weight_class, fighters in rankings.items():
    for rank, details in fighters.items():
        feature = {
            "type": "Feature",
            "geometry": {
                "type": "Point",
                "coordinates": [details['longitude'], details['latitude']]
            },
            "properties": {
                "name": details['name'],
                "gym": details['gym_location'],
                "rank": rank
            }
        }
        geojson["features"].append(feature)

# Save to a GeoJSON file
with open('data/fighter_gyms_2024-07-30.geojson', 'w') as f:
    json.dump(geojson, f, indent=4)

# %%
import csv
from datetime import datetime

# Define the CSV filename with today's date
csv_filename = f"rankings_{datetime.today().strftime('%Y-%m-%d')}.csv"

# Function to read the existing CSV file and return a dictionary of rows
def read_existing_data(filename):
    data = {}
    try:
        with open(filename, mode='r', newline='') as file:
            reader = csv.DictReader(file)
            for row in reader:
                name = row["Name"]
                data[name] = row
    except FileNotFoundError:
        # If the file doesn't exist, return an empty dictionary
        pass
    return data

# Function to write data to CSV file
def write_csv(data, filename):
    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(["Name", "Gym", "Weight", "Rank", "latitude", "longitude"])
        # Write the rows
        for row in data.values():
            writer.writerow([
                row["Name"],
                row["Gym"],
                row["Weight"],
                row["Rank"],
                row["latitude"],
                row["longitude"]
            ])

# Read existing data
existing_data = read_existing_data(csv_filename)

# Create a list to hold the updated rows for the CSV
updated_data = {}

# Iterate over the rankings dictionary and update or add new rows
for weight_class, fighters in rankings.items():
    for rank, fighter_info in fighters.items():
        name = fighter_info["name"]
        updated_data[name] = {
            "Name": name,
            "Gym": fighter_info["gym_location"],
            "Weight": weight_class,
            "Rank": rank,
            "latitude": fighter_info["latitude"],
            "longitude": fighter_info["longitude"]
        }

# Write the updated data to the CSV file
write_csv(updated_data, csv_filename)

print(f"CSV file '{csv_filename}' updated successfully.")
# Out:
# CSV file 'rankings_2024-07-31.csv' updated successfully.
